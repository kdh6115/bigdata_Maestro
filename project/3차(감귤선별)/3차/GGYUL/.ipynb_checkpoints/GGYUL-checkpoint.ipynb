# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split  # 임의로 분할 , 
# 트레이닝 셋과 검증 셋
import matplotlib.pyplot as plt
import random
import os

# %%
print(os.listdir("C:/Users/ICT01_12/Desktop/project"))
# 파일 불러오기
# Out:
# ['aproperty']

# %%
FAST_RUN = False
IMAGE_WIDTH=256
IMAGE_HEIGHT=256
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
# 컬러니까 3개 채널.

# %%
filenames = os.listdir("C:/Users/ICT01_12/Desktop/project/aproperty")
categories = []  ## 저장 카테고리 
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'aproperty':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df = df.sample(frac = 1).reset_index(drop = True)

# %%
df
# Out:
#                   filename  category
# 0    besangpoom. (253).jpg         0
# 1    besangpoom. (245).jpg         0
# 2     aproperty. (436).jpg         1
# 3     aproperty. (410).jpg         1
# 4    besangpoom. (300).jpg         0
# ..                     ...       ...
# 408  besangpoom. (257).jpg         0
# 409  besangpoom. (355).jpg         0
# 410   aproperty. (291).jpg         1
# 411   aproperty. (295).jpg         1
# 412  besangpoom. (219).jpg         0
#
# [413 rows x 2 columns]

# %%
df['category'].value_counts().plot.bar()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout
from keras.layers import Flatten, Dense, Activation, BatchNormalization

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (IMAGE_WIDTH,
                                                               IMAGE_HEIGHT,
                                                               IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size =(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation= 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size =(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

# 완전연결층 
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(2, activation = 'softmax'))  # 상품과 비상품 두개 분류

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.summary()  ## 모델 구조 시각화
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 254, 254, 32)      896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 254, 254, 32)      128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 125, 125, 64)      18496
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 64)      256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 60, 60, 128)       73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 60, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30, 30, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 115200)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               58982912
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 59,080,130
# Trainable params: 59,078,658
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping,ReduceLROnPlateau

# %%
earlystop = EarlyStopping(patience = 10)

# 이전 에폭과 비교했을때 loss가 감소하지 않는다면 10번 참고 에폭을 중단해라.

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
## 에폭이 1번동안에 모델 성능이 향성되지 않는다면 learning_rate를 줄여라

# %%
callbacks = [earlystop,learning_rate_reduction ]
# 콜백에 두가지 함수를 추가.

# %%
# 0과 1을 문자열로 교체. 

df["category"] = df["category"].replace({0: 'besangpoom', 1: 'aproperty'})

# %%
train_df, validate_df = train_test_split(df, test_size = 0.3, random_state = 42)
# train_test_split 함수는 행렬을 훈련 부분 집합과 검증 부분 집합으로 무작위로 나누다. 
# test_size = 샘플의 비율

# 인덱스를 재설정한다. 
train_df = train_df.reset_index(drop = True)
validate_df = validate_df.reset_index(drop = True)

# %%
train_df['category'].value_counts().plot.bar()
# 훈련세트가 어떻게 나누어져 있는가

# %%
validate_df['category'].value_counts().plot.bar()
# 검증셋이 어떻게 나누어져 있는가.

# %%
total_train = train_df.shape[0]  # 교육 데이터 289개 
total_validate = validate_df.shape[0] # 검증 데이터 124개
batch_size=15

# %%
total_train
# Out:
# 289

# %%
total_validate
# Out:
# 124

# %%
# ImageDataGenerator를 이용해서 데이터 셋의 크기 확장. ..

train_datagen = ImageDataGenerator(
    rotation_range=15,  # 회전 범위
    rescale=1./255,   # 이미지의 디지털 스케일링...?
    shear_range=0.1,   #?
    zoom_range=0.2,    #줌의 범위 
    horizontal_flip=True,   #수평
    width_shift_range=0.1,  # 수평적 시프트 범위
    height_shift_range=0.1   # 수직 시프트 범위 
)

# 변환 값: (x,y)
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "C:/Users/ICT01_12/Desktop/project/aproperty",  # 이경로에 포함된 모든 이미지.  
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE, #사이즈
    class_mode='categorical',
    batch_size=batch_size  # 배치 데이터의 크기
)
# Out:
# Found 289 validated image filenames belonging to 2 classes.

# %%
train_df.shape
# Out:
# (289, 2)

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "C:/Users/ICT01_12/Desktop/project/aproperty", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 124 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "C:/Users/ICT01_12/Desktop/project/aproperty", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
epochs=3 if FAST_RUN else 20
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 19/19 [==============================] - 67s 4s/step - loss: 0.2708 - accuracy: 0.9234 - val_loss: 1.6457 - val_accuracy: 0.5750
# Epoch 2/20
# 19/19 [==============================] - 77s 4s/step - loss: 0.1555 - accuracy: 0.9489 - val_loss: 11.0875 - val_accuracy: 0.5596
# Epoch 3/20
# 19/19 [==============================] - 73s 4s/step - loss: 0.3174 - accuracy: 0.9635 - val_loss: 5.9005 - val_accuracy: 0.5413
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 4/20
# 19/19 [==============================] - 70s 4s/step - loss: 0.1017 - accuracy: 0.9708 - val_loss: 4.8489 - val_accuracy: 0.6330
# Epoch 5/20
# 19/19 [==============================] - 69s 4s/step - loss: 0.0302 - accuracy: 0.9860 - val_loss: 4.0251 - val_accuracy: 0.5138
# Epoch 6/20
# 19/19 [==============================] - 63s 3s/step - loss: 0.0227 - accuracy: 0.9886 - val_loss: 4.2249 - val_accuracy: 0.6147
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 7/20
# 19/19 [==============================] - 62s 3s/step - loss: 0.0972 - accuracy: 0.9781 - val_loss: 2.6528 - val_accuracy: 0.5963
# Epoch 8/20
# 19/19 [==============================] - 62s 3s/step - loss: 0.0465 - accuracy: 0.9854 - val_loss: 4.6250 - val_accuracy: 0.5046
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 9/20
# 19/19 [==============================] - 62s 3s/step - loss: 0.0225 - accuracy: 0.9964 - val_loss: 1.7514 - val_accuracy: 0.6147
# Epoch 10/20
# 19/19 [==============================] - 67s 4s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.3403 - val_accuracy: 0.5917
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 11/20
# 19/19 [==============================] - 77s 4s/step - loss: 0.0301 - accuracy: 0.9927 - val_loss: 0.4862 - val_accuracy: 0.7431
# Epoch 12/20
# 19/19 [==============================] - 60s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5116 - val_accuracy: 0.7706
# Epoch 13/20
# 19/19 [==============================] - 63s 3s/step - loss: 0.0380 - accuracy: 0.9854 - val_loss: 0.1043 - val_accuracy: 0.8624
# Epoch 14/20
# 19/19 [==============================] - 64s 3s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9174
# Epoch 15/20
# 19/19 [==============================] - 60s 3s/step - loss: 0.0142 - accuracy: 0.9962 - val_loss: 0.2413 - val_accuracy: 0.9633
# Epoch 16/20
# 19/19 [==============================] - 64s 3s/step - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.0033 - val_accuracy: 0.9633
# Epoch 17/20
# 19/19 [==============================] - 62s 3s/step - loss: 0.0139 - accuracy: 0.9927 - val_loss: 1.8114e-04 - val_accuracy: 0.9725
# Epoch 18/20
# 19/19 [==============================] - 62s 3s/step - loss: 0.0250 - accuracy: 0.9927 - val_loss: 0.0000e+00 - val_accuracy: 0.9908
# Epoch 19/20
# 19/19 [==============================] - 64s 3s/step - loss: 0.0315 - accuracy: 0.9854 - val_loss: 3.2234e-05 - val_accuracy: 0.9917
# Epoch 20/20
# 19/19 [==============================] - 76s 4s/step - loss: 0.1287 - accuracy: 0.9927 - val_loss: 0.0000e+00 - val_accuracy: 0.9908

# %%
model.save_weights("model.h5")

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
test_filenames = os.listdir("C:/Users/ICT01_12/Desktop/project/aproperty")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "C:/Users/ICT01_12/Desktop/project/aproperty", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 413 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'] = test_df['category'].replace({ 'aproperty': 1, 'besangpoom': 0 })

# %%
test_df['category'].value_counts().plot.bar()
