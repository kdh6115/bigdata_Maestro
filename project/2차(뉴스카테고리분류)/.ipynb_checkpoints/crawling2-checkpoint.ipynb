# %%
from konlpy.tag import Twitter
from gensim.models import Word2Vec
import csv
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from konlpy.tag import Kkma
from konlpy.tag import Komoran
from konlpy.tag import Okt
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\ICT01_21\Anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data_set.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a41c870e81cd> in <module>
# ----> 1 data_set.head()
#
# NameError: name 'data_set' is not defined

# %%
data_set = pd.read_excel("data.xlsx")
data_set = data_set.iloc[:,1:]
data_set.rename({0:'news'},axis=1, inplace= True)
data_label = {1:'culture',2:'global',3:'politic',4:'society',5:'economy'}
# Out:
# C:\Users\ICT01_18\Anaconda3\envs\tf_test\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in range(len(data_set)) :
    data_set['news'][i] = re.sub('[^a-zA-Z0-9 ㄱ-ㅣ가-힣]', '', data_set['news'][i])
# Out:
# C:\Users\ICT01_18\Anaconda3\envs\tf_test\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_set = data_set.sample(frac=1)

# %%
data_set.head()
# Out:
#                                     news  label
# 19571     홍콩 시위대가 쏜 불화살에 맞은 경찰양측 극렬 대치종합      2
# 31226   트럼프 김정은 적대행동하면 잃을게 너무 많아사실상 모든것종      3
# 10444  오늘도 다이어트 연예인들이 먹고 살 뺐다는 다이어트 보조제들      1
# 1021           덕수궁 담벼락에 흰천누구를 위한 퍼포먼스였을까      1
# 32774       정부 중국에 500만달러 인도적 지원 제공 적극검토      3

# %%
def get_noun(text):
    tokenizer = Twitter()
    nouns = tokenizer.nouns(text)
    return [n for n in nouns]

def get_noun2(text):
    tokenizer = Hannanum()
    nouns = tokenizer.nouns(text)
    return [n for n in nouns]

def get_noun3(text):
    tokenizer = Okt()
    nouns = tokenizer.nouns(text)
    return [n for n in nouns]

def get_morphs3(text):
    tokenizer = Okt()
    morphs = tokenizer.morphs(text)
    return [n for n in morphs]

def get_noun4(text):
    tokenizer = Komoran()
    nouns = tokenizer.nouns(text)
    return [n for n in nouns]

# %%
CV = CountVectorizer(tokenizer = get_noun3)
CV2 = CountVectorizer(tokenizer = get_morphs3)

# %%
CV = CountVectorizer(tokenizer = get_noun3)

# %%
train_set, test_set = train_test_split(data_set, test_size = 0.3, random_state = 42)

# %%
dic = { 
        '기자':'가',
        '연합뉴스': '가',
        '뉴스':'가',
        '사진': '가',
        '무단': '가',
        '금지':'가',
        '영상': '가',
        '동아일보':'가',
        '제공':'가',
        '전문':'가',
        '종합':'가',
        '단독':'가',
        '속보':'가',
        '이슈':'가',
        '속':'가'}

# %%
data_set = data_set.replace(dic,'')

# %%
fit_transform = CV.fit_transform(train_set["news"])

# %%
data_set
# Out:
#                                      news  label
# 19571      홍콩 시위대가 쏜 불화살에 맞은 경찰양측 극렬 대치종합      2
# 31226    트럼프 김정은 적대행동하면 잃을게 너무 많아사실상 모든것종      3
# 10444   오늘도 다이어트 연예인들이 먹고 살 뺐다는 다이어트 보조제들      1
# 1021            덕수궁 담벼락에 흰천누구를 위한 퍼포먼스였을까      1
# 32774        정부 중국에 500만달러 인도적 지원 제공 적극검토      3
# ...                                   ...    ...
# 42704  김경수 등 청탁 감찰 중단에 영향 미쳤냐 판사 물음에 조국 그      4
# 32677      속보 안철수 바른미래당 비대위원장 맡겠다 손학규에 제안      3
# 9211           김건모 콘서트서 강용석 제기한 성폭행 의혹 언급      1
# 53914                 사라지는 화이트칼라중산층 몰락 가속      5
# 28931              이해찬 정말로 말이 안나오는 상황이 왔다      3
#
# [54900 rows x 2 columns]

# %%
CV.vocabulary_
# Out:
# {'이경규': 13721,
#  '마장면': 5366,
#  '출시': 17592,
#  '가격': 2,
#  '후기': 20887,
#  '트럼프': 18704,
#  '화웨이': 20632,
#  '전면': 15190,
#  '금지': 2193,
#  '국가': 1758,
#  '비상': 8303,
#  '사태': 8728,
#  '선포': 9349,
#  '갈등': 238,
#  '격랑': 753,
#  '속': 9780,
#  '알바니아': 11380,
#  '최악': 17427,
#  '지진': 16456,
#  '발생': 6911,
#  '최소': 17417,
#  '명': 5792,
#  '사망': 8582,
#  '존스홉킨스대': 15883,
#  '신종': 10786,
#  '코로나': 18022,
#  '실시간': 10862,
#  '확산': 20670,
#  '지도': 16354,
#  '공개': 1253,
#  '고민정': 1077,
#  '아수라': 11138,
#  '걱정': 625,
#  '대한민국': 4120,
#  '터키': 18431,
#  '쿠르드': 18124,
#  '군사작전': 1893,
#  '임박': 14388,
#  '대통령실': 4094,
#  '곧': 1198,
#  '시리아': 10534,
#  '국경': 1773,
#  '종': 15907,
#  '서울': 9202,
#  '상': 8896,
#  '하위': 19674,
#  '차': 16792,
#  '최대': 17391,
#  '무인기': 6178,
#  '격추': 767,
#  '보복': 7591,
#  '공격': 1255,
#  '승인': 10474,
#  '철회': 17128,
#  '속보': 9790,
#  '북한': 7982,
#  '단거리': 3727,
#  '미사일': 6431,
#  '신뢰': 10710,
#  '위반': 13193,
#  '생각': 9075,
#  '안해': 11359,
#  '친박': 17753,
#  '핵심': 20099,
#  '이정현': 14013,
#  '은혜': 13581,
#  '보답': 7553,
#  '위해': 13240,
#  '순천': 10211,
#  '내년': 3171,
#  '총선': 17363,
#  '수도권': 9989,
#  '어산지': 11731,
#  '체포': 17244,
#  '에콰도르': 11927,
#  '현직': 20320,
#  '대통령': 4092,
#  '가시': 90,
#  '친': 17741,
#  '설전': 9387,
#  '안젤리나': 11341,
#  '졸리': 15891,
#  '장남': 14806,
#  '매덕스': 5572,
#  '왜': 12700,
#  '연세대': 12164,
#  '입학': 14507,
#  '한국': 19752,
#  '김현아': 2715,
#  '문': 6234,
#  '한센병': 19807,
#  '비유': 8333,
#  '논란': 3425,
#  '정치권': 15583,
#  '막말': 5412,
#  '악순': 11252,
#  '송혜교': 9920,
#  '작품': 14718,
#  '남자': 3107,
#  '강용석': 408,
#  '배우': 7124,
#  '실명': 10843,
#  '언급': 11787,
#  '신인': 10767,
#  '오늘': 12431,
#  '자택': 14675,
#  '채': 16969,
#  '발견': 6872,
#  '등산': 4706,
#  '복': 7665,
#  '해외여행': 20060,
#  '미식': 6460,
#  '미술관': 6444,
#  '등': 4690,
#  '테마': 18461,
#  '여행': 12060,
#  '여': 11972,
#  '동남아': 4457,
#  '북핵': 7985,
#  '민생': 6530,
#  '고민': 1076,
#  '듯': 4687,
#  '현빈': 20303,
#  '인민': 14170,
#  '수트': 10138,
#  '손예진': 9841,
#  '위': 13176,
#  '명품': 5853,
#  '액션': 11506,
#  '강릉': 364,
#  '박': 6662,
#  '호갱': 20406,
#  '호텔': 20466,
#  '의정부': 13699,
#  '사건': 8530,
#  '남편': 3124,
#  '시신': 10573,
#  '극단': 2072,
#  '선택': 9347,
#  '한일': 19835,
#  '전쟁': 15281,
#  '언론': 11792,
#  '미국': 6378,
#  '일본': 14301,
#  '입장': 14492,
#  '지지': 16451,
#  '여론': 12002,
#  '전': 15127,
#  '포착': 19265,
#  '한미': 19789,
#  '일': 14260,
#  '각기': 169,
#  '다른': 3641,
#  '태풍': 18398,
#  '다나스': 3623,
#  '예상': 12388,
#  '경로': 863,
#  '장마전선': 14830,
#  '대만': 3974,
#  '홍콩': 20570,
#  '정부': 15478,
#  '시위': 10584,
#  '촉발': 17323,
#  '살인': 8834,
#  '범': 7312,
#  '나경원': 2884,
#  '토착': 18524,
#  '왜구': 12702,
#  '좌파': 15972,
#  '낙인': 2970,
#  '달창': 3815,
#  '달빛': 3808,
#  '창문': 16954,
#  '줄': 16134,
#  '검찰': 691,
#  '조국': 15721,
#  '청문회': 17169,
#  '당일': 3886,
#  '부인': 7884,
#  '정경': 15418,
#  '심': 10903,
#  '전격': 15130,
#  '총장': 17368,
#  '날씨': 3046,
#  '휴일': 20990,
#  '충청': 17647,
#  '이남': 13741,
#  '봄비': 7756,
#  '공기': 1269,
#  '깨끗': 2769,
#  '지구': 16334,
#  '허파': 20219,
#  '아마존': 11103,
#  '화재': 20642,
#  '전세계': 15228,
#  '우려': 12887,
#  '브라질': 8185,
#  '주권': 15997,
#  '침해': 17806,
#  '외신': 12745,
#  '운동': 12972,
#  '여학생': 12059,
#  '편지': 19139,
#  '대륙': 3962,
#  '심금': 10910,
#  '중학교': 16262,
#  '미혼': 6505,
#  '여교사': 11983,
#  '제자': 15668,
#  '성관계': 9421,
#  '경찰': 934,
#  '처벌': 17020,
#  '종합': 15954,
#  '자궁경부암': 14537,
#  '층': 17692,
#  '증가': 16297,
#  '방치': 7059,
#  '시골': 10500,
#  '마을': 5347,
#  '헛간': 20249,
#  '신생아': 10735,
#  '온몸': 12578,
#  '벌레': 7304,
#  '흔적': 21026,
#  '종이': 15940,
#  '사각형': 8527,
#  '테스트': 18463,
#  '변질': 7465,
#  '공시': 1318,
#  '기생충': 2321,
#  '아카데미상': 11211,
#  '감독': 263,
#  '각본': 177,
#  '개': 456,
#  '부문': 7837,
#  '후보': 20900,
#  '김연': 2580,
#  '철': 17093,
#  '박영선': 6724,
#  '진영': 16589,
#  '임명': 14385,
#  '재송부': 14989,
#  '요청': 12815,
#  '유명': 13316,
#  '방송인': 7017,
#  '제이': 15664,
#  '레노': 4983,
#  '또': 4809,
#  '개고기': 459,
#  '농담': 3452,
#  '밀실': 6579,
#  '재앙': 14994,
#  '구원': 1710,
#  '리얼돌': 5215,
#  '공장': 1345,
#  '직접': 16533,
#  '황교안': 20748,
#  '당무': 3871,
#  '복귀': 7670,
#  '성은': 9486,
#  '쇄신': 9927,
#  '당직': 3890,
#  '일괄': 14269,
#  '사퇴': 8731,
#  '설마': 9370,
#  '우리': 12891,
#  '집도': 16670,
#  '불량': 8088,
#  '레미콘': 4989,
#  '성신양회': 9474,
#  '유죄': 13409,
#  '확정': 20677,
#  '정상외교': 15483,
#  '혼자': 20505,
#  '감당': 262,
#  '이낙연': 13740,
#  '총리와': 17356,
#  '런던': 4967,
#  '브리지': 8206,
#  '테러범': 18457,
#  '흉기': 21000,
#  '영웅': 12318,
#  '용의자': 12857,
#  '테러': 18456,
#  '전과자': 15136,
#  '노트': 3397,
#  '리베이트': 5190,
#  '예약': 12400,
#  '취소': 17665,
#  '속출': 9803,
#  '웃통': 13026,
#  '록키': 5101,
#  '사진': 8705,
#  '얼굴': 11804,
#  '합성': 19927,
#  '트윗': 18731,
#  '윤석열': 13514,
#  '막판': 5421,
#  '위증': 13227,
#  '변호사': 7474,
#  '소개': 9643,
#  '녹음': 3416,
#  '파일': 18885,
#  '컨테이너': 17960,
#  '구': 1640,
#  '모두': 5880,
#  '중국인': 16180,
#  '밀': 6561,
#  '입국': 14445,
#  '참사': 16920,
#  '추정': 17519,
#  '불볕': 8112,
#  '더위': 4157,
#  '호우': 20443,
#  '비바람': 8291,
#  '단계': 3729,
#  '열대저압부': 12229,
#  '오키나와': 12531,
#  '남쪽': 3117,
#  '해상': 20038,
#  '접': 15386,
#  '영향': 12341,
#  '지지도': 16452,
#  '최저': 17448,
#  '치': 17695,
#  '상승': 8957,
#  '봄': 7748,
#  '시샘': 10560,
#  '눈': 3513,
#  '대관령': 3917,
#  '강원': 412,
#  '중부': 16209,
#  '산지': 8793,
#  '대설': 4010,
#  '특보': 18754,
#  '대구': 3920,
#  '칠성': 17782,
#  '시장': 10588,
#  '경호': 956,
#  '총기': 17346,
#  '일자': 14344,
#  '청와대': 17185,
#  '하루': 19637,
#  '두': 4571,
#  '차례': 16814,
#  '해명': 20024,
#  '적자': 15117,
#  '한전': 19845,
#  '경영': 895,
#  '점수': 15369,
#  '양호': 11682,
#  '준': 16121,
#  '터미널': 18423,
#  '성범죄': 9452,
#  '이춘': 14061,
#  '재': 14937,
#  '추억': 17511,
#  '자백': 14579,
#  '사실': 8632,
#  '땐': 4787,
#  '역대': 12071,
#  '흉악': 21005,
#  '취준생': 17673,
#  '딸': 4764,
#  '번': 7271,
#  '장애인': 14883,
#  '행사': 20134,
#  '눈물': 3525,
#  '새벽': 9034,
#  '머스트': 5663,
#  '비': 8241,
#  '사고': 8533,
#  '일정': 14350,
#  '탓': 18361,
#  '비하인드': 8368,
#  '뉴스': 3549,
#  '발언': 6917,
#  '도둑': 4254,
#  '적반하장': 15103,
#  '로사': 5073,
#  '한반도': 19794,
#  '근접': 2115,
#  '부산': 7846,
#  '울산': 13007,
#  '부처님': 7916,
#  '업': 11839,
#  '수': 9953,
#  '보살': 7594,
#  '조계종': 15718,
#  '기부': 2308,
#  '경기': 855,
#  '파주': 18890,
#  '아프리카': 11229,
#  '돼지': 4562,
#  '열병': 12235,
#  '확진': 20680,
#  '국내': 1779,
#  '방역': 7032,
#  '구멍': 1675,
#  '군산': 1896,
#  '테슬라': 18464,
#  '바': 6600,
#  '이튼': 14079,
#  '생산': 9099,
#  '기지': 2384,
#  '김혁': 2708,
#  '김성혜': 2546,
#  '숙청': 10182,
#  '김영철': 2588,
#  '강제': 425,
#  '노': 3301,
#  '역설': 12083,
#  '대한': 4118,
#  '반': 6788,
#  '람': 4914,
#  '내': 3162,
#  '체면': 17218,
#  '시진핑': 10598,
#  '이별': 13828,
#  '전야': 15246,
#  '미래': 6408,
#  '찬회': 16894,
#  '도화선': 4347,
#  '현대차': 20300,
#  '독일': 4386,
#  '점유': 15374,
#  '율': 13538,
#  '최고': 17384,
#  '판매량': 18923,
#  '신보라': 10721,
#  '아이': 11166,
#  '안고': 11275,
#  '본회의': 7737,
#  '의장': 13694,
#  '허가': 20174,
#  '여부': 12011,
#  '고심': 1110,
#  '강경화': 342,
#  '공유': 1336,
#  '인식': 14200,
#  '나문희': 2906,
#  '배종옥': 7133,
#  '전국': 15143,
#  '그': 2026,
#  '사연': 8644,
#  '우리은행': 12898,
#  '원금': 13056,
#  '손실': 9839,
#  '첫': 17138,
#  '이재명': 13996,
#  '지사': 16391,
#  '결단': 790,
#  '국토부': 1858,
#  '버스': 7254,
#  '파업': 18867,
#  '저지': 15079,
#  '동분서주': 4488,
#  '코끼리': 18009,
#  '사자': 8682,
#  '코뿔소': 18037,
#  '밀렵': 6570,
#  '지역구': 16418,
#  '광복절': 1516,
#  '숙면': 10167,
#  '민경욱': 6519,
#  '구설수': 1695,
#  '집': 16655,
#  '송년회': 9882,
#  '세': 9532,
#  '가지': 144,
#  '요리': 12793,
#  '끝': 2867,
#  '공룡': 1283,
#  '단지': 3775,
#  '분양': 8027,
#  '소화': 9774,
#  '근로자': 2100,
#  '날': 3032,
#  '누': 3492,
#  '출근': 17572,
#  '쉬': 10254,
#  '카스': 17848,
#  '테라': 18455,
#  '흥행': 21054,
#  '깜짝': 2764,
#  '개월': 506,
#  '출고': 17567,
#  '린다': 5251,
#  '내일': 3200,
#  '곳': 1243,
#  '이상': 13858,
#  '살': 8809,
#  '티몬': 18796,
#  '직원': 16524,
#  '연봉': 12156,
#  '달새': 3809,
#  '과천': 1423,
#  '셋값': 9624,
#  '값': 328,
#  '백색': 7176,
#  '제외': 15660,
#  '블랙리스트': 8214,
#  '란': 4911,
#  '칠': 17779,
#  '환경부': 20690,
#  '의혹': 13711,
#  '적': 15091,
#  '현장': 20317,
#  '진짜': 16607,
#  '조의': 15824,
#  '금': 2132,
#  '안': 11267,
#  '신격호': 10669,
#  '빈소': 8407,
#  '뒷이야기': 4641,
#  '개혁': 540,
#  '불행': 8158,
#  '국방부': 1813,
#  '군사': 1887,
#  '합의': 19932,
#  '김건모': 2431,
#  '성폭행': 9517,
#  '주장': 16073,
#  '여성': 12016,
#  '맞고소': 5550,
#  '음란물': 13592,
#  '유포': 13441,
#  '로이킴': 5084,
#  '기습': 2333,
#  '팬': 19011,
#  '퇴': 18609,
#  '출하': 17615,
#  '스탠다드': 10360,
#  '감사': 271,
#  '실시': 10861,
#  '응모': 13632,
#  '이벤트': 13826,
#  '지하': 16481,
#  '주차장': 16089,
#  '충전': 17642,
#  '전기자동차': 15151,
#  '주의보': 16066,
#  '공정위': 1348,
#  '판': 18909,
#  '토스': 18512,
#  '그룹': 2058,
#  '부당': 7811,
#  '지원': 16428,
#  '조사': 15761,
#  '착수': 16874,
#  '정두언': 15440,
#  '의원': 13688,
#  '전날': 15156,
#  '방송출연': 7019,
#  '요식업': 12803,
#  '운영': 12984,
#  '부진': 7910,
#  '르노': 5164,
#  '삼성': 8864,
#  '도루묵': 4262,
#  '협력': 20353,
#  '경제': 916,
#  '조': 15708,
#  '산책': 8796,
#  '필리핀': 19574,
#  '망고': 5524,
#  '타격': 18233,
#  '직장': 16528,
#  '회사': 20830,
#  '선': 9268,
#  '노조': 3386,
#  '때문': 4785,
#  '곤욕': 1194,
#  '이란': 13773,
#  '핵': 20092,
#  '탈퇴': 18343,
#  '프로그램': 19449,
#  '제한': 15695,
#  '무디스': 6109,
#  '불매운동': 8097,
#  '위협': 13245,
#  '이세돌': 13892,
#  '허무': 20192,
#  '한돌': 19777,
#  '개발자': 483,
#  '당황': 3900,
#  '중국': 16175,
#  '반도체': 6809,
#  '뺨': 8484,
#  '선회': 9355,
#  '하나': 19610,
#  '디스플레이': 4732,
#  '불똥': 8087,
#  '절반': 15347,
#  '국민연금': 1803,
#  '월': 13121,
#  '평균': 19151,
#  '진중권': 16605,
#  '정봉주': 15477,
#  '정치': 15580,
#  '사람': 8567,
#  '법대': 7332,
#  '운동권': 12973,
#  '공부': 1302,
#  '친구': 17743,
#  '운명': 12978,
#  '유치원': 13429,
#  '법': 7329,
#  '안건': 11272,
#  '필리버스터': 19573,
#  '신청': 10795,
#  '와글와글': 12623,
#  '인물': 14169,
#  '영화': 12345,
#  '오해': 12546,
#  '동맹국': 4470,
#  '보이콧': 7621,
#  '동두천': 4465,
#  '대설주의보': 4011,
#  '해제': 20073,
#  '오후': 12550,
#  '다시': 3667,
#  '눈발': 3527,
#  '노땅': 3324,
#  '정당': 15433,
#  '금수': 2170,
#  '청년': 17156,
#  '혼쭐': 20512,
#  '난': 2989,
#  '모빌리티': 5917,
#  '완성': 12645,
#  '차도': 16804,
#  '운전': 12987,
#  '최민수': 17404,
#  '징역': 16722,
#  '취업': 17667,
#  '수당': 9987,
#  '물품': 6342,
#  '식비': 10645,
#  '무면허': 6127,
#  '음주운전': 13616,
#  '초등생': 17270,
#  '자매': 14570,
#  '부모': 7835,
#  '중상': 16213,
#  '최진실': 17461,
#  '투병': 18644,
#  '루푸스': 5139,
#  '천': 17037,
#  '병': 7495,
#  '까닭': 2751,
#  '임대': 14380,
#  '수입': 10105,
#  '주택': 16097,
#  '앞': 11443,
#  '소득세': 9671,
#  '희토류': 21070,
#  '수출': 10130,
#  '전투기': 15309,
#  '못': 6046,
#  '정유미': 15530,
#  '회복': 20827,
#  '중': 16149,
#  '노인': 3382,
#  '폐렴': 19198,
#  '링링': 5267,
#  '피해': 19555,
#  '심각': 10904,
#  '일부': 14315,
#  '건물': 642,
#  '파손': 18862,
#  '안철수': 11349,
#  '이준석': 14029,
#  '박탈': 6771,
#  '분당': 7999,
#  '가속': 79,
#  '방화': 7078,
#  '사상': 8618,
#  '횡설수설': 20864,
#  '롯데': 5113,
#  '월드': 13130,
#  '타워': 18254,
#  '불꽃': 8079,
#  '축제': 17548,
#  '전역': 15250,
#  '약': 11573,
#  '관람': 1457,
#  '이스라엘군': 13913,
#  '발포': 6940,
#  '팔레스타인': 18946,
#  '휴가': 20977,
#  '성전환': 9495,
#  '수술': 10061,
#  '군인': 1904,
#  '여군': 11985,
#  '복무': 7677,
#  '김민희': 2499,
#  '외도': 12723,
#  '홍상수': 20549,
#  '이혼': 14105,
#  '단독': 3738,
#  '아들': 11076,
#  '논문': 3429,
#  '교신저자': 1593,
#  '나': 2879,
#  '부탁': 7927,
#  '카드': 17824,
#  '대통령제': 4095,
#  '탄핵': 18313,
#  '절차': 15356,
#  '뒷짐': 4643,
#  '진': 16550,
#  '너': 3242,
#  '옆집': 12361,
#  '아령': 11088,
#  '해': 19997,
#  '재산': 14978,
#  '펑펑': 19069,
#  '막': 5399,
#  '기상청': 2316,
#  '리자': 5221,
#  '예보': 12379,
#  '수정': 10110,
#  '제네시스': 15623,
#  '기아차': 2337,
#  '디': 4724,
#  '파워': 18876,
#  '신차': 10792,
#  '품질': 19406,
#  '석권': 9249,
#  '대첩': 4077,
#  '과열': 1410,
#  '부친': 7925,
#  '동생': 4491,
#  '처': 17011,
#  '송곳': 9877,
#  '검증': 689,
#  '전지현': 15294,
#  '스타': 10345,
#  '찜': 16787,
#  '그림': 2066,
#  '노벨상': 3347,
#  '샐러리맨': 9065,
#  '출신': 17594,
#  '리튬전지': 5239,
#  '창시자': 16959,
#  '손님': 9819,
#  '은행': 13576,
#  '뒤': 4615,
#  '신고': 10675,
#  '둘': 4604,
#  '소유권': 9739,
#  '답': 3842,
#  '불매': 8096,
#  '재고': 14949,
#  '아사히': 11131,
#  '유통': 13434,
#  '기한': 2398,
#  '언제': 11801,
#  '완전': 12652,
#  '고용': 1126,
#  '더니': 4148,
#  '열정': 12244,
#  '페이': 19092,
#  '대출': 4085,
#  '무조건': 6195,
#  '아파트': 11226,
#  '보험금': 7653,
#  '차량': 16811,
#  '추락': 17494,
#  '살해': 8845,
#  '구속': 1699,
#  '새': 9021,
#  '투자': 18666,
#  '순위': 10201,
#  '재건축': 14943,
#  '자고': 14531,
#  '과격': 1390,
#  '처방': 17018,
#  '몰래': 6015,
#  '통신망': 18567,
#  '내부': 3184,
#  '문건': 6235,
#  '폭로': 19296,
#  '부동산': 7818,
#  '업자': 11848,
#  '감금': 260,
#  '조폭': 15855,
#  '영장': 12323,
#  '과거': 1388,
#  '잘못': 14741,
#  '스스로': 10307,
#  '매우': 5591,
#  '의미': 13661,
#  '마약': 5338,
#  '음주': 13615,
#  '모델': 5876,
#  '예학영': 12415,
#  '오토바이': 12534,
#  '적발': 15104,
#  '한화': 19879,
#  '아시아나': 11146,
#  '항공': 19958,
#  '인수': 14193,
#  '참여': 16925,
#  '빨치산': 8469,
#  '상징': 8991,
#  '오진우': 12523,
#  '백화': 7209,
#  '원초': 13107,
#  '대소': 4016,
#  '비리': 8282,
#  '설': 9358,
#  '주둔': 16005,
#  '이라크': 13769,
#  '공군기지': 1265,
#  '박격포': 6663,
#  '발': 6868,
#  '부상': 7848,
#  '총알': 17366,
#  '택시': 18408,
#  '혁신': 20288,
#  '심야': 10932,
#  '승차': 10480,
#  '실험': 10897,
#  '앵커': 11527,
#  '소득': 9669,
#  '빅데이터': 8384,
#  '분석': 8017,
#  '결혼': 833,
#  '빈익빈': 8410,
#  '부익부': 7883,
#  '국민': 1801,
#  '청원': 17187,
#  '최': 17379,
#  '당혹': 3899,
#  '누나': 3497,
#  '방한': 7072,
#  '남매': 3074,
#  '강화도': 452,
#  '섬': 9401,
#  '시설': 10564,
#  '함': 19894,
#  '박도': 6678,
#  '미스터리': 6454,
#  '악수': 11251,
#  '마주': 5368,
#  '무역': 6166,
#  '당국': 3859,
#  '보복조치': 7592,
#  '실무': 10844,
#  '회의': 20844,
#  '규모': 2012,
#  '무기': 6087,
#  '판매': 18922,
#  '새해': 9047,
#  '여론조사': 12003,
#  '심판': 10951,
#  '론': 5102,
#  '우세': 12915,
#  '달': 3789,
#  '맏': 5479,
#  '사위': 8657,
#  '조운': 15816,
#  '이사장': 13850,
#  '세종': 9585,
#  '이라크전쟁': 13771,
#  '개시': 500,
#  '단추': 3778,
#  '볼턴': 7744,
#  '레이더': 5002,
#  '유정': 13403,
#  '재혼': 15024,
#  '고씨': 1111,
#  '고소': 1096,
#  '정황': 15605,
#  '요즘': 12812,
#  '임신': 14403,
#  '부석': 7851,
#  '폭행': 19330,
#  '당한': 3898,
#  '임신부': 14405,
#  '포토': 19274,
#  '아침': 11206,
#  '풍경': 19408,
#  '병원': 7521,
#  '이국': 13730,
#  '교수': 1591,
#  '절단': 15339,
#  '위기': 13181,
#  '장병': 14850,
#  '팔': 18938,
#  '인터뷰': 14239,
#  '몸짱': 6040,
#  '변신': 7454,
#  '에바': 11881,
#  '몸매': 6031,
#  '몸값': 6030,
#  '매각': 5561,
#  '연내': 12131,
#  '아버지': 11120,
#  '쌍둥이': 10995,
#  '손주': 9850,
#  '생매장': 9089,
#  '북상': 7964,
#  '신기록': 10683,
#  '빙속': 8438,
#  '이영하': 13940,
#  '별세': 7489,
#  '외교': 12715,
#  '결례': 792,
#  '기자': 2362,
#  '철수': 17107,
#  '요구': 12782,
#  '통화': 18608,
#  '가치': 153,
#  '절하': 15360,
#  '상계관세': 8901,
#  '겨냥': 728,
#  '전남편': 15159,
#  '혈흔': 20343,
#  '졸피뎀': 15899,
#  '증언': 16316,
#  '반응': 6838,
#  '보': 7530,
#  '총리': 17353,
#  '소재': 9747,
#  '부품': 7934,
#  '의존': 13701,
#  '탈피': 18345,
#  '전화위복': 15329,
#  '것': 701,
#  '베트남': 7402,
#  '착륙': 16872,
#  '티웨이': 18808,
#  '여객기': 11976,
#  '의문': 13659,
#  '충돌': 17629,
#  '아몬드': 11112,
#  '비결': 8246,
#  '좌우': 15965,
#  '습관': 10444,
#  '탄도미사일': 18294,
#  '발사': 6908,
#  '간과': 194,
#  '안보리': 11309,
#  '제재': 15674,
#  '한국인': 19757,
#  '칼럼니스트': 17883,
#  '총': 17338,
#  '더': 4145,
#  '크게': 18152,
#  '한진': 19860,
#  '모녀': 5870,
#  '법정': 7353,
#  '애기': 11469,
#  '엄마': 11822,
#  '강신우': 398,
#  '닥치': 3722,
#  '벨기에': 7416,
#  '국왕': 1832,
#  '극찬': 2087,
#  '초콜릿': 17313,
#  '인도': 14153,
#  '집단성폭행': 16666,
#  '사살': 8617,
#  '꽃': 2820,
#  '세례': 9549,
#  '물산': 6319,
#  '분식회계': 8022,
#  '프랑스': 19438,
#  '확': 20664,
#  '진자': 16596,
#  '상태': 8995,
#  '위중': 13226,
#  '이매리': 13791,
#  '술시': 10230,
#  '강요': 407,
#  '웃기': 13022,
#  '감히': 314,
#  '말대꾸': 5486,
#  '만': 5424,
#  '무차별': 6204,
#  '남': 3053,
#  '위안부': 13206,
#  '성노예': 9433,
#  '확인': 20674,
#  '적용': 15113,
#  '혐의': 20346,
#  '소환': 9777,
#  '마법': 5313,
#  '가루': 52,
#  '라면': 4874,
#  '스프': 10423,
#  '무엇': 6165,
#  '여의도': 12032,
#  '중진': 16253,
#  '입': 14439,
#  '모락모락': 5887,
#  '호주': 20454,
#  ...}

# %%
word_test = CV.vocabulary_

# %%
word_test = np.asarray(word_test)

# %%
word_test.keys()
# Out:
# dict_keys(['이경규', '마장면', '출시', '가격', '후기', '트럼프', '화웨이', '전면', '금지', '국가', '비상', '사태', '선포', '갈등', '격랑', '속', '알바니아', '최악', '지진', '발생', '최소', '명', '사망', '존스홉킨스대', '신종', '코로나', '실시간', '확산', '지도', '공개', '고민정', '아수라', '걱정', '대한민국', '터키', '쿠르드', '군사작전', '임박', '대통령실', '곧', '시리아', '국경', '종', '서울', '상', '하위', '차', '최대', '무인기', '격추', '보복', '공격', '승인', '철회', '속보', '북한', '단거리', '미사일', '신뢰', '위반', '생각', '안해', '친박', '핵심', '이정현', '은혜', '보답', '위해', '순천', '내년', '총선', '수도권', '어산지', '체포', '에콰도르', '현직', '대통령', '가시', '친', '설전', '안젤리나', '졸리', '장남', '매덕스', '왜', '연세대', '입학', '한국', '김현아', '문', '한센병', '비유', '논란', '정치권', '막말', '악순', '송혜교', '작품', '남자', '강용석', '배우', '실명', '언급', '신인', '오늘', '자택', '채', '발견', '등산', '복', '해외여행', '미식', '미술관', '등', '테마', '여행', '여', '동남아', '북핵', '민생', '고민', '듯', '현빈', '인민', '수트', '손예진', '위', '명품', '액션', '강릉', '박', '호갱', '호텔', '의정부', '사건', '남편', '시신', '극단', '선택', '한일', '전쟁', '언론', '미국', '일본', '입장', '지지', '여론', '전', '포착', '한미', '일', '각기', '다른', '태풍', '다나스', '예상', '경로', '장마전선', '대만', '홍콩', '정부', '시위', '촉발', '살인', '범', '나경원', '토착', '왜구', '좌파', '낙인', '달창', '달빛', '창문', '줄', '검찰', '조국', '청문회', '당일', '부인', '정경', '심', '전격', '총장', '날씨', '휴일', '충청', '이남', '봄비', '공기', '깨끗', '지구', '허파', '아마존', '화재', '전세계', '우려', '브라질', '주권', '침해', '외신', '운동', '여학생', '편지', '대륙', '심금', '중학교', '미혼', '여교사', '제자', '성관계', '경찰', '처벌', '종합', '자궁경부암', '층', '증가', '방치', '시골', '마을', '헛간', '신생아', '온몸', '벌레', '흔적', '종이', '사각형', '테스트', '변질', '공시', '기생충', '아카데미상', '감독', '각본', '개', '부문', '후보', '김연', '철', '박영선', '진영', '임명', '재송부', '요청', '유명', '방송인', '제이', '레노', '또', '개고기', '농담', '밀실', '재앙', '구원', '리얼돌', '공장', '직접', '황교안', '당무', '복귀', '성은', '쇄신', '당직', '일괄', '사퇴', '설마', '우리', '집도', '불량', '레미콘', '성신양회', '유죄', '확정', '정상외교', '혼자', '감당', '이낙연', '총리와', '런던', '브리지', '테러범', '흉기', '영웅', '용의자', '테러', '전과자', '노트', '리베이트', '예약', '취소', '속출', '웃통', '록키', '사진', '얼굴', '합성', '트윗', '윤석열', '막판', '위증', '변호사', '소개', '녹음', '파일', '컨테이너', '구', '모두', '중국인', '밀', '입국', '참사', '추정', '불볕', '더위', '호우', '비바람', '단계', '열대저압부', '오키나와', '남쪽', '해상', '접', '영향', '지지도', '최저', '치', '상승', '봄', '시샘', '눈', '대관령', '강원', '중부', '산지', '대설', '특보', '대구', '칠성', '시장', '경호', '총기', '일자', '청와대', '하루', '두', '차례', '해명', '적자', '한전', '경영', '점수', '양호', '준', '터미널', '성범죄', '이춘', '재', '추억', '자백', '사실', '땐', '역대', '흉악', '취준생', '딸', '번', '장애인', '행사', '눈물', '새벽', '머스트', '비', '사고', '일정', '탓', '비하인드', '뉴스', '발언', '도둑', '적반하장', '로사', '한반도', '근접', '부산', '울산', '부처님', '업', '수', '보살', '조계종', '기부', '경기', '파주', '아프리카', '돼지', '열병', '확진', '국내', '방역', '구멍', '군산', '테슬라', '바', '이튼', '생산', '기지', '김혁', '김성혜', '숙청', '김영철', '강제', '노', '역설', '대한', '반', '람', '내', '체면', '시진핑', '이별', '전야', '미래', '찬회', '도화선', '현대차', '독일', '점유', '율', '최고', '판매량', '신보라', '아이', '안고', '본회의', '의장', '허가', '여부', '고심', '강경화', '공유', '인식', '나문희', '배종옥', '전국', '그', '사연', '우리은행', '원금', '손실', '첫', '이재명', '지사', '결단', '국토부', '버스', '파업', '저지', '동분서주', '코끼리', '사자', '코뿔소', '밀렵', '지역구', '광복절', '숙면', '민경욱', '구설수', '집', '송년회', '세', '가지', '요리', '끝', '공룡', '단지', '분양', '소화', '근로자', '날', '누', '출근', '쉬', '카스', '테라', '흥행', '깜짝', '개월', '출고', '린다', '내일', '곳', '이상', '살', '티몬', '직원', '연봉', '달새', '과천', '셋값', '값', '백색', '제외', '블랙리스트', '란', '칠', '환경부', '의혹', '적', '현장', '진짜', '조의', '금', '안', '신격호', '빈소', '뒷이야기', '개혁', '불행', '국방부', '군사', '합의', '김건모', '성폭행', '주장', '여성', '맞고소', '음란물', '유포', '로이킴', '기습', '팬', '퇴', '출하', '스탠다드', '감사', '실시', '응모', '이벤트', '지하', '주차장', '충전', '전기자동차', '주의보', '공정위', '판', '토스', '그룹', '부당', '지원', '조사', '착수', '정두언', '의원', '전날', '방송출연', '요식업', '운영', '부진', '르노', '삼성', '도루묵', '협력', '경제', '조', '산책', '필리핀', '망고', '타격', '직장', '회사', '선', '노조', '때문', '곤욕', '이란', '핵', '탈퇴', '프로그램', '제한', '무디스', '불매운동', '위협', '이세돌', '허무', '한돌', '개발자', '당황', '중국', '반도체', '뺨', '선회', '하나', '디스플레이', '불똥', '절반', '국민연금', '월', '평균', '진중권', '정봉주', '정치', '사람', '법대', '운동권', '공부', '친구', '운명', '유치원', '법', '안건', '필리버스터', '신청', '와글와글', '인물', '영화', '오해', '동맹국', '보이콧', '동두천', '대설주의보', '해제', '오후', '다시', '눈발', '노땅', '정당', '금수', '청년', '혼쭐', '난', '모빌리티', '완성', '차도', '운전', '최민수', '징역', '취업', '수당', '물품', '식비', '무면허', '음주운전', '초등생', '자매',  ...

# %%
word_test
a = []
b= ()
for i in range(len(word_test)):
    a.append([list(word_test.keys())[i],list(word_test.values())[i]])

# %%
a
# Out:
# [['이경규', 13721],
#  ['마장면', 5366],
#  ['출시', 17592],
#  ['가격', 2],
#  ['후기', 20887],
#  ['트럼프', 18704],
#  ['화웨이', 20632],
#  ['전면', 15190],
#  ['금지', 2193],
#  ['국가', 1758],
#  ['비상', 8303],
#  ['사태', 8728],
#  ['선포', 9349],
#  ['갈등', 238],
#  ['격랑', 753],
#  ['속', 9780],
#  ['알바니아', 11380],
#  ['최악', 17427],
#  ['지진', 16456],
#  ['발생', 6911],
#  ['최소', 17417],
#  ['명', 5792],
#  ['사망', 8582],
#  ['존스홉킨스대', 15883],
#  ['신종', 10786],
#  ['코로나', 18022],
#  ['실시간', 10862],
#  ['확산', 20670],
#  ['지도', 16354],
#  ['공개', 1253],
#  ['고민정', 1077],
#  ['아수라', 11138],
#  ['걱정', 625],
#  ['대한민국', 4120],
#  ['터키', 18431],
#  ['쿠르드', 18124],
#  ['군사작전', 1893],
#  ['임박', 14388],
#  ['대통령실', 4094],
#  ['곧', 1198],
#  ['시리아', 10534],
#  ['국경', 1773],
#  ['종', 15907],
#  ['서울', 9202],
#  ['상', 8896],
#  ['하위', 19674],
#  ['차', 16792],
#  ['최대', 17391],
#  ['무인기', 6178],
#  ['격추', 767],
#  ['보복', 7591],
#  ['공격', 1255],
#  ['승인', 10474],
#  ['철회', 17128],
#  ['속보', 9790],
#  ['북한', 7982],
#  ['단거리', 3727],
#  ['미사일', 6431],
#  ['신뢰', 10710],
#  ['위반', 13193],
#  ['생각', 9075],
#  ['안해', 11359],
#  ['친박', 17753],
#  ['핵심', 20099],
#  ['이정현', 14013],
#  ['은혜', 13581],
#  ['보답', 7553],
#  ['위해', 13240],
#  ['순천', 10211],
#  ['내년', 3171],
#  ['총선', 17363],
#  ['수도권', 9989],
#  ['어산지', 11731],
#  ['체포', 17244],
#  ['에콰도르', 11927],
#  ['현직', 20320],
#  ['대통령', 4092],
#  ['가시', 90],
#  ['친', 17741],
#  ['설전', 9387],
#  ['안젤리나', 11341],
#  ['졸리', 15891],
#  ['장남', 14806],
#  ['매덕스', 5572],
#  ['왜', 12700],
#  ['연세대', 12164],
#  ['입학', 14507],
#  ['한국', 19752],
#  ['김현아', 2715],
#  ['문', 6234],
#  ['한센병', 19807],
#  ['비유', 8333],
#  ['논란', 3425],
#  ['정치권', 15583],
#  ['막말', 5412],
#  ['악순', 11252],
#  ['송혜교', 9920],
#  ['작품', 14718],
#  ['남자', 3107],
#  ['강용석', 408],
#  ['배우', 7124],
#  ['실명', 10843],
#  ['언급', 11787],
#  ['신인', 10767],
#  ['오늘', 12431],
#  ['자택', 14675],
#  ['채', 16969],
#  ['발견', 6872],
#  ['등산', 4706],
#  ['복', 7665],
#  ['해외여행', 20060],
#  ['미식', 6460],
#  ['미술관', 6444],
#  ['등', 4690],
#  ['테마', 18461],
#  ['여행', 12060],
#  ['여', 11972],
#  ['동남아', 4457],
#  ['북핵', 7985],
#  ['민생', 6530],
#  ['고민', 1076],
#  ['듯', 4687],
#  ['현빈', 20303],
#  ['인민', 14170],
#  ['수트', 10138],
#  ['손예진', 9841],
#  ['위', 13176],
#  ['명품', 5853],
#  ['액션', 11506],
#  ['강릉', 364],
#  ['박', 6662],
#  ['호갱', 20406],
#  ['호텔', 20466],
#  ['의정부', 13699],
#  ['사건', 8530],
#  ['남편', 3124],
#  ['시신', 10573],
#  ['극단', 2072],
#  ['선택', 9347],
#  ['한일', 19835],
#  ['전쟁', 15281],
#  ['언론', 11792],
#  ['미국', 6378],
#  ['일본', 14301],
#  ['입장', 14492],
#  ['지지', 16451],
#  ['여론', 12002],
#  ['전', 15127],
#  ['포착', 19265],
#  ['한미', 19789],
#  ['일', 14260],
#  ['각기', 169],
#  ['다른', 3641],
#  ['태풍', 18398],
#  ['다나스', 3623],
#  ['예상', 12388],
#  ['경로', 863],
#  ['장마전선', 14830],
#  ['대만', 3974],
#  ['홍콩', 20570],
#  ['정부', 15478],
#  ['시위', 10584],
#  ['촉발', 17323],
#  ['살인', 8834],
#  ['범', 7312],
#  ['나경원', 2884],
#  ['토착', 18524],
#  ['왜구', 12702],
#  ['좌파', 15972],
#  ['낙인', 2970],
#  ['달창', 3815],
#  ['달빛', 3808],
#  ['창문', 16954],
#  ['줄', 16134],
#  ['검찰', 691],
#  ['조국', 15721],
#  ['청문회', 17169],
#  ['당일', 3886],
#  ['부인', 7884],
#  ['정경', 15418],
#  ['심', 10903],
#  ['전격', 15130],
#  ['총장', 17368],
#  ['날씨', 3046],
#  ['휴일', 20990],
#  ['충청', 17647],
#  ['이남', 13741],
#  ['봄비', 7756],
#  ['공기', 1269],
#  ['깨끗', 2769],
#  ['지구', 16334],
#  ['허파', 20219],
#  ['아마존', 11103],
#  ['화재', 20642],
#  ['전세계', 15228],
#  ['우려', 12887],
#  ['브라질', 8185],
#  ['주권', 15997],
#  ['침해', 17806],
#  ['외신', 12745],
#  ['운동', 12972],
#  ['여학생', 12059],
#  ['편지', 19139],
#  ['대륙', 3962],
#  ['심금', 10910],
#  ['중학교', 16262],
#  ['미혼', 6505],
#  ['여교사', 11983],
#  ['제자', 15668],
#  ['성관계', 9421],
#  ['경찰', 934],
#  ['처벌', 17020],
#  ['종합', 15954],
#  ['자궁경부암', 14537],
#  ['층', 17692],
#  ['증가', 16297],
#  ['방치', 7059],
#  ['시골', 10500],
#  ['마을', 5347],
#  ['헛간', 20249],
#  ['신생아', 10735],
#  ['온몸', 12578],
#  ['벌레', 7304],
#  ['흔적', 21026],
#  ['종이', 15940],
#  ['사각형', 8527],
#  ['테스트', 18463],
#  ['변질', 7465],
#  ['공시', 1318],
#  ['기생충', 2321],
#  ['아카데미상', 11211],
#  ['감독', 263],
#  ['각본', 177],
#  ['개', 456],
#  ['부문', 7837],
#  ['후보', 20900],
#  ['김연', 2580],
#  ['철', 17093],
#  ['박영선', 6724],
#  ['진영', 16589],
#  ['임명', 14385],
#  ['재송부', 14989],
#  ['요청', 12815],
#  ['유명', 13316],
#  ['방송인', 7017],
#  ['제이', 15664],
#  ['레노', 4983],
#  ['또', 4809],
#  ['개고기', 459],
#  ['농담', 3452],
#  ['밀실', 6579],
#  ['재앙', 14994],
#  ['구원', 1710],
#  ['리얼돌', 5215],
#  ['공장', 1345],
#  ['직접', 16533],
#  ['황교안', 20748],
#  ['당무', 3871],
#  ['복귀', 7670],
#  ['성은', 9486],
#  ['쇄신', 9927],
#  ['당직', 3890],
#  ['일괄', 14269],
#  ['사퇴', 8731],
#  ['설마', 9370],
#  ['우리', 12891],
#  ['집도', 16670],
#  ['불량', 8088],
#  ['레미콘', 4989],
#  ['성신양회', 9474],
#  ['유죄', 13409],
#  ['확정', 20677],
#  ['정상외교', 15483],
#  ['혼자', 20505],
#  ['감당', 262],
#  ['이낙연', 13740],
#  ['총리와', 17356],
#  ['런던', 4967],
#  ['브리지', 8206],
#  ['테러범', 18457],
#  ['흉기', 21000],
#  ['영웅', 12318],
#  ['용의자', 12857],
#  ['테러', 18456],
#  ['전과자', 15136],
#  ['노트', 3397],
#  ['리베이트', 5190],
#  ['예약', 12400],
#  ['취소', 17665],
#  ['속출', 9803],
#  ['웃통', 13026],
#  ['록키', 5101],
#  ['사진', 8705],
#  ['얼굴', 11804],
#  ['합성', 19927],
#  ['트윗', 18731],
#  ['윤석열', 13514],
#  ['막판', 5421],
#  ['위증', 13227],
#  ['변호사', 7474],
#  ['소개', 9643],
#  ['녹음', 3416],
#  ['파일', 18885],
#  ['컨테이너', 17960],
#  ['구', 1640],
#  ['모두', 5880],
#  ['중국인', 16180],
#  ['밀', 6561],
#  ['입국', 14445],
#  ['참사', 16920],
#  ['추정', 17519],
#  ['불볕', 8112],
#  ['더위', 4157],
#  ['호우', 20443],
#  ['비바람', 8291],
#  ['단계', 3729],
#  ['열대저압부', 12229],
#  ['오키나와', 12531],
#  ['남쪽', 3117],
#  ['해상', 20038],
#  ['접', 15386],
#  ['영향', 12341],
#  ['지지도', 16452],
#  ['최저', 17448],
#  ['치', 17695],
#  ['상승', 8957],
#  ['봄', 7748],
#  ['시샘', 10560],
#  ['눈', 3513],
#  ['대관령', 3917],
#  ['강원', 412],
#  ['중부', 16209],
#  ['산지', 8793],
#  ['대설', 4010],
#  ['특보', 18754],
#  ['대구', 3920],
#  ['칠성', 17782],
#  ['시장', 10588],
#  ['경호', 956],
#  ['총기', 17346],
#  ['일자', 14344],
#  ['청와대', 17185],
#  ['하루', 19637],
#  ['두', 4571],
#  ['차례', 16814],
#  ['해명', 20024],
#  ['적자', 15117],
#  ['한전', 19845],
#  ['경영', 895],
#  ['점수', 15369],
#  ['양호', 11682],
#  ['준', 16121],
#  ['터미널', 18423],
#  ['성범죄', 9452],
#  ['이춘', 14061],
#  ['재', 14937],
#  ['추억', 17511],
#  ['자백', 14579],
#  ['사실', 8632],
#  ['땐', 4787],
#  ['역대', 12071],
#  ['흉악', 21005],
#  ['취준생', 17673],
#  ['딸', 4764],
#  ['번', 7271],
#  ['장애인', 14883],
#  ['행사', 20134],
#  ['눈물', 3525],
#  ['새벽', 9034],
#  ['머스트', 5663],
#  ['비', 8241],
#  ['사고', 8533],
#  ['일정', 14350],
#  ['탓', 18361],
#  ['비하인드', 8368],
#  ['뉴스', 3549],
#  ['발언', 6917],
#  ['도둑', 4254],
#  ['적반하장', 15103],
#  ['로사', 5073],
#  ['한반도', 19794],
#  ['근접', 2115],
#  ['부산', 7846],
#  ['울산', 13007],
#  ['부처님', 7916],
#  ['업', 11839],
#  ['수', 9953],
#  ['보살', 7594],
#  ['조계종', 15718],
#  ['기부', 2308],
#  ['경기', 855],
#  ['파주', 18890],
#  ['아프리카', 11229],
#  ['돼지', 4562],
#  ['열병', 12235],
#  ['확진', 20680],
#  ['국내', 1779],
#  ['방역', 7032],
#  ['구멍', 1675],
#  ['군산', 1896],
#  ['테슬라', 18464],
#  ['바', 6600],
#  ['이튼', 14079],
#  ['생산', 9099],
#  ['기지', 2384],
#  ['김혁', 2708],
#  ['김성혜', 2546],
#  ['숙청', 10182],
#  ['김영철', 2588],
#  ['강제', 425],
#  ['노', 3301],
#  ['역설', 12083],
#  ['대한', 4118],
#  ['반', 6788],
#  ['람', 4914],
#  ['내', 3162],
#  ['체면', 17218],
#  ['시진핑', 10598],
#  ['이별', 13828],
#  ['전야', 15246],
#  ['미래', 6408],
#  ['찬회', 16894],
#  ['도화선', 4347],
#  ['현대차', 20300],
#  ['독일', 4386],
#  ['점유', 15374],
#  ['율', 13538],
#  ['최고', 17384],
#  ['판매량', 18923],
#  ['신보라', 10721],
#  ['아이', 11166],
#  ['안고', 11275],
#  ['본회의', 7737],
#  ['의장', 13694],
#  ['허가', 20174],
#  ['여부', 12011],
#  ['고심', 1110],
#  ['강경화', 342],
#  ['공유', 1336],
#  ['인식', 14200],
#  ['나문희', 2906],
#  ['배종옥', 7133],
#  ['전국', 15143],
#  ['그', 2026],
#  ['사연', 8644],
#  ['우리은행', 12898],
#  ['원금', 13056],
#  ['손실', 9839],
#  ['첫', 17138],
#  ['이재명', 13996],
#  ['지사', 16391],
#  ['결단', 790],
#  ['국토부', 1858],
#  ['버스', 7254],
#  ['파업', 18867],
#  ['저지', 15079],
#  ['동분서주', 4488],
#  ['코끼리', 18009],
#  ['사자', 8682],
#  ['코뿔소', 18037],
#  ['밀렵', 6570],
#  ['지역구', 16418],
#  ['광복절', 1516],
#  ['숙면', 10167],
#  ['민경욱', 6519],
#  ['구설수', 1695],
#  ['집', 16655],
#  ['송년회', 9882],
#  ['세', 9532],
#  ['가지', 144],
#  ['요리', 12793],
#  ['끝', 2867],
#  ['공룡', 1283],
#  ['단지', 3775],
#  ['분양', 8027],
#  ['소화', 9774],
#  ['근로자', 2100],
#  ['날', 3032],
#  ['누', 3492],
#  ['출근', 17572],
#  ['쉬', 10254],
#  ['카스', 17848],
#  ['테라', 18455],
#  ['흥행', 21054],
#  ['깜짝', 2764],
#  ['개월', 506],
#  ['출고', 17567],
#  ['린다', 5251],
#  ['내일', 3200],
#  ['곳', 1243],
#  ['이상', 13858],
#  ['살', 8809],
#  ['티몬', 18796],
#  ['직원', 16524],
#  ['연봉', 12156],
#  ['달새', 3809],
#  ['과천', 1423],
#  ['셋값', 9624],
#  ['값', 328],
#  ['백색', 7176],
#  ['제외', 15660],
#  ['블랙리스트', 8214],
#  ['란', 4911],
#  ['칠', 17779],
#  ['환경부', 20690],
#  ['의혹', 13711],
#  ['적', 15091],
#  ['현장', 20317],
#  ['진짜', 16607],
#  ['조의', 15824],
#  ['금', 2132],
#  ['안', 11267],
#  ['신격호', 10669],
#  ['빈소', 8407],
#  ['뒷이야기', 4641],
#  ['개혁', 540],
#  ['불행', 8158],
#  ['국방부', 1813],
#  ['군사', 1887],
#  ['합의', 19932],
#  ['김건모', 2431],
#  ['성폭행', 9517],
#  ['주장', 16073],
#  ['여성', 12016],
#  ['맞고소', 5550],
#  ['음란물', 13592],
#  ['유포', 13441],
#  ['로이킴', 5084],
#  ['기습', 2333],
#  ['팬', 19011],
#  ['퇴', 18609],
#  ['출하', 17615],
#  ['스탠다드', 10360],
#  ['감사', 271],
#  ['실시', 10861],
#  ['응모', 13632],
#  ['이벤트', 13826],
#  ['지하', 16481],
#  ['주차장', 16089],
#  ['충전', 17642],
#  ['전기자동차', 15151],
#  ['주의보', 16066],
#  ['공정위', 1348],
#  ['판', 18909],
#  ['토스', 18512],
#  ['그룹', 2058],
#  ['부당', 7811],
#  ['지원', 16428],
#  ['조사', 15761],
#  ['착수', 16874],
#  ['정두언', 15440],
#  ['의원', 13688],
#  ['전날', 15156],
#  ['방송출연', 7019],
#  ['요식업', 12803],
#  ['운영', 12984],
#  ['부진', 7910],
#  ['르노', 5164],
#  ['삼성', 8864],
#  ['도루묵', 4262],
#  ['협력', 20353],
#  ['경제', 916],
#  ['조', 15708],
#  ['산책', 8796],
#  ['필리핀', 19574],
#  ['망고', 5524],
#  ['타격', 18233],
#  ['직장', 16528],
#  ['회사', 20830],
#  ['선', 9268],
#  ['노조', 3386],
#  ['때문', 4785],
#  ['곤욕', 1194],
#  ['이란', 13773],
#  ['핵', 20092],
#  ['탈퇴', 18343],
#  ['프로그램', 19449],
#  ['제한', 15695],
#  ['무디스', 6109],
#  ['불매운동', 8097],
#  ['위협', 13245],
#  ['이세돌', 13892],
#  ['허무', 20192],
#  ['한돌', 19777],
#  ['개발자', 483],
#  ['당황', 3900],
#  ['중국', 16175],
#  ['반도체', 6809],
#  ['뺨', 8484],
#  ['선회', 9355],
#  ['하나', 19610],
#  ['디스플레이', 4732],
#  ['불똥', 8087],
#  ['절반', 15347],
#  ['국민연금', 1803],
#  ['월', 13121],
#  ['평균', 19151],
#  ['진중권', 16605],
#  ['정봉주', 15477],
#  ['정치', 15580],
#  ['사람', 8567],
#  ['법대', 7332],
#  ['운동권', 12973],
#  ['공부', 1302],
#  ['친구', 17743],
#  ['운명', 12978],
#  ['유치원', 13429],
#  ['법', 7329],
#  ['안건', 11272],
#  ['필리버스터', 19573],
#  ['신청', 10795],
#  ['와글와글', 12623],
#  ['인물', 14169],
#  ['영화', 12345],
#  ['오해', 12546],
#  ['동맹국', 4470],
#  ['보이콧', 7621],
#  ['동두천', 4465],
#  ['대설주의보', 4011],
#  ['해제', 20073],
#  ['오후', 12550],
#  ['다시', 3667],
#  ['눈발', 3527],
#  ['노땅', 3324],
#  ['정당', 15433],
#  ['금수', 2170],
#  ['청년', 17156],
#  ['혼쭐', 20512],
#  ['난', 2989],
#  ['모빌리티', 5917],
#  ['완성', 12645],
#  ['차도', 16804],
#  ['운전', 12987],
#  ['최민수', 17404],
#  ['징역', 16722],
#  ['취업', 17667],
#  ['수당', 9987],
#  ['물품', 6342],
#  ['식비', 10645],
#  ['무면허', 6127],
#  ['음주운전', 13616],
#  ['초등생', 17270],
#  ['자매', 14570],
#  ['부모', 7835],
#  ['중상', 16213],
#  ['최진실', 17461],
#  ['투병', 18644],
#  ['루푸스', 5139],
#  ['천', 17037],
#  ['병', 7495],
#  ['까닭', 2751],
#  ['임대', 14380],
#  ['수입', 10105],
#  ['주택', 16097],
#  ['앞', 11443],
#  ['소득세', 9671],
#  ['희토류', 21070],
#  ['수출', 10130],
#  ['전투기', 15309],
#  ['못', 6046],
#  ['정유미', 15530],
#  ['회복', 20827],
#  ['중', 16149],
#  ['노인', 3382],
#  ['폐렴', 19198],
#  ['링링', 5267],
#  ['피해', 19555],
#  ['심각', 10904],
#  ['일부', 14315],
#  ['건물', 642],
#  ['파손', 18862],
#  ['안철수', 11349],
#  ['이준석', 14029],
#  ['박탈', 6771],
#  ['분당', 7999],
#  ['가속', 79],
#  ['방화', 7078],
#  ['사상', 8618],
#  ['횡설수설', 20864],
#  ['롯데', 5113],
#  ['월드', 13130],
#  ['타워', 18254],
#  ['불꽃', 8079],
#  ['축제', 17548],
#  ['전역', 15250],
#  ['약', 11573],
#  ['관람', 1457],
#  ['이스라엘군', 13913],
#  ['발포', 6940],
#  ['팔레스타인', 18946],
#  ['휴가', 20977],
#  ['성전환', 9495],
#  ['수술', 10061],
#  ['군인', 1904],
#  ['여군', 11985],
#  ['복무', 7677],
#  ['김민희', 2499],
#  ['외도', 12723],
#  ['홍상수', 20549],
#  ['이혼', 14105],
#  ['단독', 3738],
#  ['아들', 11076],
#  ['논문', 3429],
#  ['교신저자', 1593],
#  ['나', 2879],
#  ['부탁', 7927],
#  ['카드', 17824],
#  ['대통령제', 4095],
#  ['탄핵', 18313],
#  ['절차', 15356],
#  ['뒷짐', 4643],
#  ['진', 16550],
#  ['너', 3242],
#  ['옆집', 12361],
#  ['아령', 11088],
#  ['해', 19997],
#  ['재산', 14978],
#  ['펑펑', 19069],
#  ['막', 5399],
#  ['기상청', 2316],
#  ['리자', 5221],
#  ['예보', 12379],
#  ['수정', 10110],
#  ['제네시스', 15623],
#  ['기아차', 2337],
#  ['디', 4724],
#  ['파워', 18876],
#  ['신차', 10792],
#  ['품질', 19406],
#  ['석권', 9249],
#  ['대첩', 4077],
#  ['과열', 1410],
#  ['부친', 7925],
#  ['동생', 4491],
#  ['처', 17011],
#  ['송곳', 9877],
#  ['검증', 689],
#  ['전지현', 15294],
#  ['스타', 10345],
#  ['찜', 16787],
#  ['그림', 2066],
#  ['노벨상', 3347],
#  ['샐러리맨', 9065],
#  ['출신', 17594],
#  ['리튬전지', 5239],
#  ['창시자', 16959],
#  ['손님', 9819],
#  ['은행', 13576],
#  ['뒤', 4615],
#  ['신고', 10675],
#  ['둘', 4604],
#  ['소유권', 9739],
#  ['답', 3842],
#  ['불매', 8096],
#  ['재고', 14949],
#  ['아사히', 11131],
#  ['유통', 13434],
#  ['기한', 2398],
#  ['언제', 11801],
#  ['완전', 12652],
#  ['고용', 1126],
#  ['더니', 4148],
#  ['열정', 12244],
#  ['페이', 19092],
#  ['대출', 4085],
#  ['무조건', 6195],
#  ['아파트', 11226],
#  ['보험금', 7653],
#  ['차량', 16811],
#  ['추락', 17494],
#  ['살해', 8845],
#  ['구속', 1699],
#  ['새', 9021],
#  ['투자', 18666],
#  ['순위', 10201],
#  ['재건축', 14943],
#  ['자고', 14531],
#  ['과격', 1390],
#  ['처방', 17018],
#  ['몰래', 6015],
#  ['통신망', 18567],
#  ['내부', 3184],
#  ['문건', 6235],
#  ['폭로', 19296],
#  ['부동산', 7818],
#  ['업자', 11848],
#  ['감금', 260],
#  ['조폭', 15855],
#  ['영장', 12323],
#  ['과거', 1388],
#  ['잘못', 14741],
#  ['스스로', 10307],
#  ['매우', 5591],
#  ['의미', 13661],
#  ['마약', 5338],
#  ['음주', 13615],
#  ['모델', 5876],
#  ['예학영', 12415],
#  ['오토바이', 12534],
#  ['적발', 15104],
#  ['한화', 19879],
#  ['아시아나', 11146],
#  ['항공', 19958],
#  ['인수', 14193],
#  ['참여', 16925],
#  ['빨치산', 8469],
#  ['상징', 8991],
#  ['오진우', 12523],
#  ['백화', 7209],
#  ['원초', 13107],
#  ['대소', 4016],
#  ['비리', 8282],
#  ['설', 9358],
#  ['주둔', 16005],
#  ['이라크', 13769],
#  ['공군기지', 1265],
#  ['박격포', 6663],
#  ['발', 6868],
#  ['부상', 7848],
#  ['총알', 17366],
#  ['택시', 18408],
#  ['혁신', 20288],
#  ['심야', 10932],
#  ['승차', 10480],
#  ['실험', 10897],
#  ['앵커', 11527],
#  ['소득', 9669],
#  ['빅데이터', 8384],
#  ['분석', 8017],
#  ['결혼', 833],
#  ['빈익빈', 8410],
#  ['부익부', 7883],
#  ['국민', 1801],
#  ['청원', 17187],
#  ['최', 17379],
#  ['당혹', 3899],
#  ['누나', 3497],
#  ['방한', 7072],
#  ['남매', 3074],
#  ['강화도', 452],
#  ['섬', 9401],
#  ['시설', 10564],
#  ['함', 19894],
#  ['박도', 6678],
#  ['미스터리', 6454],
#  ['악수', 11251],
#  ['마주', 5368],
#  ['무역', 6166],
#  ['당국', 3859],
#  ['보복조치', 7592],
#  ['실무', 10844],
#  ['회의', 20844],
#  ['규모', 2012],
#  ['무기', 6087],
#  ['판매', 18922],
#  ['새해', 9047],
#  ['여론조사', 12003],
#  ['심판', 10951],
#  ['론', 5102],
#  ['우세', 12915],
#  ['달', 3789],
#  ['맏', 5479],
#  ['사위', 8657],
#  ['조운', 15816],
#  ['이사장', 13850],
#  ['세종', 9585],
#  ['이라크전쟁', 13771],
#  ['개시', 500],
#  ['단추', 3778],
#  ['볼턴', 7744],
#  ['레이더', 5002],
#  ['유정', 13403],
#  ['재혼', 15024],
#  ['고씨', 1111],
#  ['고소', 1096],
#  ['정황', 15605],
#  ['요즘', 12812],
#  ['임신', 14403],
#  ['부석', 7851],
#  ['폭행', 19330],
#  ['당한', 3898],
#  ['임신부', 14405],
#  ['포토', 19274],
#  ['아침', 11206],
#  ['풍경', 19408],
#  ['병원', 7521],
#  ['이국', 13730],
#  ['교수', 1591],
#  ['절단', 15339],
#  ['위기', 13181],
#  ['장병', 14850],
#  ['팔', 18938],
#  ['인터뷰', 14239],
#  ['몸짱', 6040],
#  ['변신', 7454],
#  ['에바', 11881],
#  ['몸매', 6031],
#  ['몸값', 6030],
#  ['매각', 5561],
#  ['연내', 12131],
#  ['아버지', 11120],
#  ['쌍둥이', 10995],
#  ['손주', 9850],
#  ['생매장', 9089],
#  ['북상', 7964],
#  ['신기록', 10683],
#  ['빙속', 8438],
#  ['이영하', 13940],
#  ['별세', 7489],
#  ['외교', 12715],
#  ['결례', 792],
#  ['기자', 2362],
#  ['철수', 17107],
#  ['요구', 12782],
#  ['통화', 18608],
#  ['가치', 153],
#  ['절하', 15360],
#  ['상계관세', 8901],
#  ['겨냥', 728],
#  ['전남편', 15159],
#  ['혈흔', 20343],
#  ['졸피뎀', 15899],
#  ['증언', 16316],
#  ['반응', 6838],
#  ['보', 7530],
#  ['총리', 17353],
#  ['소재', 9747],
#  ['부품', 7934],
#  ['의존', 13701],
#  ['탈피', 18345],
#  ['전화위복', 15329],
#  ['것', 701],
#  ['베트남', 7402],
#  ['착륙', 16872],
#  ['티웨이', 18808],
#  ['여객기', 11976],
#  ['의문', 13659],
#  ['충돌', 17629],
#  ['아몬드', 11112],
#  ['비결', 8246],
#  ['좌우', 15965],
#  ['습관', 10444],
#  ['탄도미사일', 18294],
#  ['발사', 6908],
#  ['간과', 194],
#  ['안보리', 11309],
#  ['제재', 15674],
#  ['한국인', 19757],
#  ['칼럼니스트', 17883],
#  ['총', 17338],
#  ['더', 4145],
#  ['크게', 18152],
#  ['한진', 19860],
#  ['모녀', 5870],
#  ['법정', 7353],
#  ['애기', 11469],
#  ['엄마', 11822],
#  ['강신우', 398],
#  ['닥치', 3722],
#  ['벨기에', 7416],
#  ['국왕', 1832],
#  ['극찬', 2087],
#  ['초콜릿', 17313],
#  ['인도', 14153],
#  ['집단성폭행', 16666],
#  ['사살', 8617],
#  ['꽃', 2820],
#  ['세례', 9549],
#  ['물산', 6319],
#  ['분식회계', 8022],
#  ['프랑스', 19438],
#  ['확', 20664],
#  ['진자', 16596],
#  ['상태', 8995],
#  ['위중', 13226],
#  ['이매리', 13791],
#  ['술시', 10230],
#  ['강요', 407],
#  ['웃기', 13022],
#  ['감히', 314],
#  ['말대꾸', 5486],
#  ['만', 5424],
#  ['무차별', 6204],
#  ['남', 3053],
#  ['위안부', 13206],
#  ['성노예', 9433],
#  ['확인', 20674],
#  ['적용', 15113],
#  ['혐의', 20346],
#  ['소환', 9777],
#  ['마법', 5313],
#  ['가루', 52],
#  ['라면', 4874],
#  ['스프', 10423],
#  ['무엇', 6165],
#  ['여의도', 12032],
#  ['중진', 16253],
#  ['입', 14439],
#  ['모락모락', 5887],
#  ['호주', 20454],
#  ...]

# %%
model = Word2Vec(a)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-56-46260bf99237> in <module>
# ----> 1 model = Word2Vec(a)
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     781             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#     782             seed=seed, hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, compute_loss=compute_loss,
# --> 783             fast_version=FAST_VERSION)
#     784
#     785     def _do_train_epoch(self, corpus_file, thread_id, offset, cython_vocab, thread_private_mem, cur_epoch,
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\base_any2vec.py in __init__(self, sentences, corpus_file, workers, vector_size, epochs, callbacks, batch_words, trim_rule, sg, alpha, window, seed, hs, negative, ns_exponent, cbow_mean, min_alpha, compute_loss, fast_version, **kwargs)
#     761                 sentences=sentences, corpus_file=corpus_file, total_examples=self.corpus_count,
#     762                 total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
# --> 763                 end_alpha=self.min_alpha, compute_loss=compute_loss)
#     764         else:
#     765             if trim_rule is not None:
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\word2vec.py in train(self, sentences, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks)
#     908             sentences=sentences, corpus_file=corpus_file, total_examples=total_examples, total_words=total_words,
#     909             epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
# --> 910             queue_factor=queue_factor, report_delay=report_delay, compute_loss=compute_loss, callbacks=callbacks)
#     911
#     912     def score(self, sentences, total_sentences=int(1e6), chunksize=100, queue_factor=2, report_delay=1):
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\base_any2vec.py in train(self, sentences, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1079             total_words=total_words, epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
#    1080             queue_factor=queue_factor, report_delay=report_delay, compute_loss=compute_loss, callbacks=callbacks,
# -> 1081             **kwargs)
#    1082
#    1083     def _get_job_params(self, cur_epoch):
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\base_any2vec.py in train(self, data_iterable, corpus_file, epochs, total_examples, total_words, queue_factor, report_delay, callbacks, **kwargs)
#     534             epochs=epochs,
#     535             total_examples=total_examples,
# --> 536             total_words=total_words, **kwargs)
#     537
#     538         for callback in self.callbacks:
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\base_any2vec.py in _check_training_sanity(self, epochs, total_examples, total_words, **kwargs)
#    1185
#    1186         if not self.wv.vocab:  # should be set by `build_vocab`
# -> 1187             raise RuntimeError("you must first build vocabulary before training the model")
#    1188         if not len(self.wv.vectors):
#    1189             raise RuntimeError("you must initialize vectors before training the model")
#
# RuntimeError: you must first build vocabulary before training the model

# %%
print('한국 : ', model['이경규'])
# Out:
# C:\Users\ICT01_18\Anaconda3\envs\tf_test\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-aa033f8bc73b> in <module>
# ----> 1 print('한국 : ', model['이경규'])
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\word2vec.py in __getitem__(self, words)
#    1119
#    1120         """
# -> 1121         return self.wv.__getitem__(words)
#    1122
#    1123     @deprecated("Method will be removed in 4.0.0, use self.wv.__contains__() instead")
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~\Anaconda3\envs\tf_test\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word '이경규' not in vocabulary"

# %%
model = Word2Vec(data_set['news'], min_count=3, iter=20, size=300,sg=1,
                window = 5)
model.init_sims(replace=True)
