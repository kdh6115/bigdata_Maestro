# %%
for col in P_GRDP.columns:
    if col == "세대수" or col == "GRDP(단위 : 백만원)":
        del P_GRDP[col]
print(P_GRDP)

# %%
import pandas as pd
inpeople = pd.read_csv("전처리완료데이터.csv")
inpeople.iloc[:, 1:2]
del inpeople["Unnamed: 0"]
df = inpeople.iloc[:, 1:]
df["카드매출액"] = df["카드매출액"]*0.01*2884
df
# Out:
#        인구    세대수  사업체수      카드매출액   wifi사용자수
# 0   50137  19526  4988  199.25556  3076786.0
# 1   43217  19336  4681  327.42052  3126565.0
# 2   56223  21026  4318  234.67108  4843117.0
# 3   36550  15563  2232  127.50164   939748.0
# 4   34684  13187  2173   96.58516  2563285.0
# 5   25003  10204  2065   84.53004   450801.0
# 6   34321  13337  1909   86.23160  1826291.0
# 7   24718  10538  1688   85.33756  1677427.0
# 8   23094   9924  1655   60.01604   729594.0
# 9   24163   8933  1651   29.07072  1517329.0
# 10  16283   7670  1561   48.79728   565136.0
# 11  25391   9542  1516   47.58600  1346005.0
# 12   7989   7851  1510   49.51828  1706470.0
# 13  17180   7753  1484   80.03100  1306846.0
# 14  14345   5952  1385   31.86820   919731.0
# 15   2993   1623  1329   45.71140  1054688.0
# 16   3984   2124  1277   26.34534    79420.0
# 17  12824   5922  1140   50.84492   882465.0
# 18  21741   8167  1106   41.09700   994026.0
# 19  19778   8438  1070   57.99724   501055.0
# ...

# %%
df["배출량"] = df["인구"]*2
df
# Out:
#        인구    세대수  사업체수      카드매출액   wifi사용자수     배출량
# 0   50137  19526  4988  199.25556  3076786.0  100274
# 1   43217  19336  4681  327.42052  3126565.0   86434
# 2   56223  21026  4318  234.67108  4843117.0  112446
# 3   36550  15563  2232  127.50164   939748.0   73100
# 4   34684  13187  2173   96.58516  2563285.0   69368
# 5   25003  10204  2065   84.53004   450801.0   50006
# 6   34321  13337  1909   86.23160  1826291.0   68642
# 7   24718  10538  1688   85.33756  1677427.0   49436
# 8   23094   9924  1655   60.01604   729594.0   46188
# 9   24163   8933  1651   29.07072  1517329.0   48326
# 10  16283   7670  1561   48.79728   565136.0   32566
# 11  25391   9542  1516   47.58600  1346005.0   50782
# 12   7989   7851  1510   49.51828  1706470.0   15978
# 13  17180   7753  1484   80.03100  1306846.0   34360
# 14  14345   5952  1385   31.86820   919731.0   28690
# 15   2993   1623  1329   45.71140  1054688.0    5986
# 16   3984   2124  1277   26.34534    79420.0    7968
# ...

# %%
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
features = '인구+세대수+사업체수+카드매출액+wifi사용자수'

# %%
y, x = dmatrices("배출량~"+features, data = df, return_type="dataframe")

vif = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
result = sm.OLS(y,x).fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    배출량   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.123e+30
# Date:                Tue, 21 Jan 2020   Prob (F-statistic):               0.00
# Time:                        16:10:20   Log-Likelihood:                 946.06
# No. Observations:                  43   AIC:                            -1880.
# Df Residuals:                      37   BIC:                            -1870.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.912e-11   1.96e-11     -3.533      0.001   -1.09e-10   -2.95e-11
# ...
